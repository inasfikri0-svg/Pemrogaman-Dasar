# %% [markdown]
# <a href="https://colab.research.google.com/github/inasfikri0-svg/Pemrogaman-Dasar/blob/main/tugas%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "Inas Fikri Dzakiyyah"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = "Pemrograman dasar"
status_lulus = False
alamat = "kav.sagulung baru blok c no.9"
hobi = "membaca"

print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
print (alamat)
print (hobi)
# Out:
# Inas Fikri Dzakiyyah
# 19
# RPE
# 3
# Pemrograman dasar
# False
# kav.sagulung baru blok c no.9
# membaca
