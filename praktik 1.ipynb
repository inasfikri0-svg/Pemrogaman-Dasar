# %% [markdown]
# <a href="https://colab.research.google.com/github/inasfikri0-svg/Pemrogaman-Dasar/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya

nama = "Inas"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = "Pemrograman dasar"
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Inas
# 19
# RPE
# 3
# Pemrograman dasar
# False
